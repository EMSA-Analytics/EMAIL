# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob

# %%
path =r'C:/Users/mjc341/desktop/UMAN 1625 A-B testingBaysean/SF_email_reports'
filenames = glob.glob(path + "/*.csv")

# %%
#create a list of filenames from the reports
EM_Results = []
for filename in filenames:
    EM_Results.append(filename[70:])

# %%
EM_Results
# Out:
# ['Career_Ctr.csv',
#  'COE_Welcome_ltr.csv',
#  'Frost_welcome_ltr.csv',
#  'MBS_REG_remind.csv',
#  'MBS_Welcome_ltr.csv',
#  'Outcomes_Values_of_UM.csv',
#  'Quest_abt_Money.csv',
#  'Registra_open_9.csv',
#  'Registra_open_9b.csv',
#  'Reg_reminder.csv',
#  'Resgistration_timeline.csv',
#  'SchoolofCOM_reg_remind.csv',
#  'SchoolofCOM_Welcome_ltr.csv',
#  'Summer_webinar.csv',
#  'UGED_Welcome_ltr.csv']

# %%
#test the path
path
# Out:
# 'C:/Users/mjc341/desktop/UMAN 1625 A-B testingBaysean/SF_email_reports'

# %%
#create a function that reads the csv files and extract the email header
import csv
def subjectline(i):
    file = open(path + "/"+ i,'r')
    csvreader=csv.reader(file)
    header = next(csvreader)
    #print(header)
    line2 =next(csvreader)
    #print(line2)
    SUBJ=line2[7]
    NameofEmail = i[:-4]
    return ["The subject line used in " + NameofEmail+ " was " + SUBJ]

# %%
#test the function
i='Career_Ctr.csv'

# %%
subjectline(i)
# Out:
# ['The subject line used in Career_Ctr was Discover and explore careers with Toppel Career Center']

# %%
#loop through the list and apply the function
HDRS= []
for item in EM_Results:
    HDRS.append(subjectline(item))
HDRS
# Out:
# [['The subject line used in Career_Ctr was Discover and explore careers with Toppel Career Center'],
#  ['The subject line used in COE_Welcome_ltr was A message from the assistant dean'],
#  ['The subject line used in Frost_welcome_ltr was A message from the Frost School of Music'],
#  ['The subject line used in MBS_REG_remind was Registration closes July 9'],
#  ['The subject line used in MBS_Welcome_ltr was Welcome to the Miami Business School'],
#  ['The subject line used in Outcomes_Values_of_UM was Experience the value of a UM education'],
#  ['The subject line used in Quest_abt_Money was Student account resources'],
#  ['The subject line used in Registra_open_9 was It?s time to register for courses!'],
#  ['The subject line used in Registra_open_9b was It?s time to register for courses!'],
#  ['The subject line used in Reg_reminder was You still need to register for classes'],
#  ['The subject line used in Resgistration_timeline was Learn next steps about your course registration process'],
#  ['The subject line used in SchoolofCOM_reg_remind was Registration closes July 9'],
#  ['The subject line used in SchoolofCOM_Welcome_ltr was A welcome from the vice dean of academic affairs'],
#  ['The subject line used in Summer_webinar was Join us for our Summer Webinar Series'],
#  ['The subject line used in UGED_Welcome_ltr was Welcome to the School of Education and Human Development']]

# %%
#create a function that opens the file and calculates the stats of the email response

# %%
def DROP_RATE(dr):
    name = pd.read_csv(path + "/"+ dr, skiprows=3, engine='python', index_col=False)
    name = name [['IntervalStartTime','Sent','Bounced', 'UniqueOpened','UniqueClicked','Unsubscribed']]
    TSent = name['Sent'].sum()
    TOpen= name['UniqueOpened'].sum()
    TUnsubsc= name['Unsubscribed'].sum()
    TClick= name['UniqueClicked'].sum()
    name['IntervalStartTime'] = pd.to_datetime(name.IntervalStartTime)
    NameofFile = ["The Stats for " + dr[:-4] + " are as follows:"]
    Stats = ["Total Emails Sent:"+ str(TSent),"Total Unique Opened: "+ str(TOpen),"Total Unsubscribed: "+ str(TUnsubsc),"Total Unique Clicks: "+str(TClick)]
    return [NameofFile,Stats]

# %%
#test the function
dr = 'Career_Ctr.csv'

# %%
DROP_RATE(dr)
# Out:
# [['The Stats for Career_Ctr are as follows:'],
#  ['Total Emails Sent:2947',
#   'Total Unique Opened: 1404',
#   'Total Unsubscribed: 0',
#   'Total Unique Clicks: 257']]

# %%
#here are the full results in a format good for a word doc only but not good for visualization
ES = []
for item in EM_Results:
    ES.append(DROP_RATE(item))
ES
# Out:
# [[['The Stats for Career_Ctr are as follows:'],
#   ['Total Emails Sent:2947',
#    'Total Unique Opened: 1404',
#    'Total Unsubscribed: 0',
#    'Total Unique Clicks: 257']],
#  [['The Stats for COE_Welcome_ltr are as follows:'],
#   ['Total Emails Sent:30',
#    'Total Unique Opened: 17',
#    'Total Unsubscribed: 0',
#    'Total Unique Clicks: 10']],
#  [['The Stats for Frost_welcome_ltr are as follows:'],
#   ['Total Emails Sent:147',
#    'Total Unique Opened: 126',
#    'Total Unsubscribed: 0',
#    'Total Unique Clicks: 23']],
#  [['The Stats for MBS_REG_remind are as follows:'],
#   ['Total Emails Sent:64',
#    'Total Unique Opened: 33',
#    'Total Unsubscribed: 0',
#    'Total Unique Clicks: 7']],
#  [['The Stats for MBS_Welcome_ltr are as follows:'],
#   ['Total Emails Sent:585',
#    'Total Unique Opened: 363',
#    'Total Unsubscribed: 0',
#    'Total Unique Clicks: 36']],
#  [['The Stats for Outcomes_Values_of_UM are as follows:'],
#   ['Total Emails Sent:2974',
#    'Total Unique Opened: 1705',
#    'Total Unsubscribed: 1',
#    'Total Unique Clicks: 101']],
#  [['The Stats for Quest_abt_Money are as follows:'],
#   ['Total Emails Sent:2953',
#    'Total Unique Opened: 1777',
#    'Total Unsubscribed: 0',
#    'Total Unique Clicks: 229']],
#  [['The Stats for Registra_open_9 are as follows:'],
#   ['Total Emails Sent:11',
#    'Total Unique Opened: 6',
#    'Total Unsubscribed: 0',
#    'Total Unique Clicks: 1']],
#  [['The Stats for Registra_open_9b are as follows:'],
#   ['Total Emails Sent:2537',
#    'Total Unique Opened: 1688',
#    'Total Unsubscribed: 0',
#    'Total Unique Clicks: 353']],
#  [['The Stats for Reg_reminder are as follows:'],
#   ['Total Emails Sent:527',
#    'Total Unique Opened: 286',
#    'Total Unsubscribed: 0',
#    'Total Unique Clicks: 59']],
#  [['The Stats for Resgistration_timeline are as follows:'],
#   ['Total Emails Sent:2234',
#    'Total Unique Opened: 1647',
#    'Total Unsubscribed: 0',
#    'Total Unique Clicks: 281']],
#  [['The Stats for SchoolofCOM_reg_remind are as follows:'],
#   ['Total Emails Sent:25',
#    'Total Unique Opened: 8',
#    'Total Unsubscribed: 0',
#    'Total Unique Clicks: 2']],
#  [['The Stats for SchoolofCOM_Welcome_ltr are as follows:'],
#   ['Total Emails Sent:168',
#    'Total Unique Opened: 117',
#    'Total Unsubscribed: 0',
#    'Total Unique Clicks: 20']],
#  [['The Stats for Summer_webinar are as follows:'],
#   ['Total Emails Sent:2851',
#    'Total Unique Opened: 1589',
#    'Total Unsubscribed: 1',
#    'Total Unique Clicks: 178']],
#  [['The Stats for UGED_Welcome_ltr are as follows:'],
#   ['Total Emails Sent:11',
#    'Total Unique Opened: 11',
#    'Total Unsubscribed: 0',
#    'Total Unique Clicks: 0']]]

# %%
#for analysis I need to put the actual numbers into the dataframe
def DROP_RATE_STATS(dr):
    name = pd.read_csv(path + "/"+ dr, skiprows=3, engine='python', index_col=False)
    name = name [['IntervalStartTime','Sent','Bounced', 'UniqueOpened','UniqueClicked','Unsubscribed']]
    TSent = name['Sent'].sum()
    TOpen= name['UniqueOpened'].sum()
    TUnsubsc= name['Unsubscribed'].sum()
    TClick= name['UniqueClicked'].sum()
    name['IntervalStartTime'] = pd.to_datetime(name.IntervalStartTime)
    NameofFile = dr[:-4]
    Stats = [TSent,TOpen,TUnsubsc,TClick]
    return [NameofFile, Stats]

# %%
#this will create a nested list of the email name and the stats
ESTAT = []
for item in EM_Results:
    ESTAT.append(DROP_RATE_STATS(item))
ESTAT
# Out:
# [['Career_Ctr', [2947, 1404, 0, 257]],
#  ['COE_Welcome_ltr', [30, 17, 0, 10]],
#  ['Frost_welcome_ltr', [147, 126, 0, 23]],
#  ['MBS_REG_remind', [64, 33, 0, 7]],
#  ['MBS_Welcome_ltr', [585, 363, 0, 36]],
#  ['Outcomes_Values_of_UM', [2974, 1705, 1, 101]],
#  ['Quest_abt_Money', [2953, 1777, 0, 229]],
#  ['Registra_open_9', [11, 6, 0, 1]],
#  ['Registra_open_9b', [2537, 1688, 0, 353]],
#  ['Reg_reminder', [527, 286, 0, 59]],
#  ['Resgistration_timeline', [2234, 1647, 0, 281]],
#  ['SchoolofCOM_reg_remind', [25, 8, 0, 2]],
#  ['SchoolofCOM_Welcome_ltr', [168, 117, 0, 20]],
#  ['Summer_webinar', [2851, 1589, 1, 178]],
#  ['UGED_Welcome_ltr', [11, 11, 0, 0]]]

# %%
#had to resolve the issue of the list of lists that was produced by the functions answer is to FLATTEN the nested list
#tried many flatten functions this one was the only one that worked and I could put it into a for loop
def lflatten(TheList):
    listIsNested = True

    while listIsNested:                 #outer loop
        keepChecking = False
        Temp = []

        for element in TheList:         #inner loop
            if isinstance(element,list):
                Temp.extend(element)
                keepChecking = True
            else:
                Temp.append(element)

        listIsNested = keepChecking     #determine if outer loop exits
        TheList = Temp[:]

    return TheList

# %%
#test the function
x = ['Career_Ctr', [2947, 1404, 0, 257]]

# %%
print(list(lflatten(x)))
# Out:
# ['Career_Ctr', 2947, 1404, 0, 257]

# %%
#put the function into the loop for the results
Flat_ESTAT = []
for item in ESTAT:
    Flat_ESTAT.append(lflatten(item))
Flat_ESTAT
# Out:
# [['Career_Ctr', 2947, 1404, 0, 257],
#  ['COE_Welcome_ltr', 30, 17, 0, 10],
#  ['Frost_welcome_ltr', 147, 126, 0, 23],
#  ['MBS_REG_remind', 64, 33, 0, 7],
#  ['MBS_Welcome_ltr', 585, 363, 0, 36],
#  ['Outcomes_Values_of_UM', 2974, 1705, 1, 101],
#  ['Quest_abt_Money', 2953, 1777, 0, 229],
#  ['Registra_open_9', 11, 6, 0, 1],
#  ['Registra_open_9b', 2537, 1688, 0, 353],
#  ['Reg_reminder', 527, 286, 0, 59],
#  ['Resgistration_timeline', 2234, 1647, 0, 281],
#  ['SchoolofCOM_reg_remind', 25, 8, 0, 2],
#  ['SchoolofCOM_Welcome_ltr', 168, 117, 0, 20],
#  ['Summer_webinar', 2851, 1589, 1, 178],
#  ['UGED_Welcome_ltr', 11, 11, 0, 0]]

# %%
#now I can create a dataframe
dfESTAT = pd.DataFrame(Flat_ESTAT[0:],columns = ['EmailName','Sent','Open','Unsub','Click'])

# %%
dfESTAT
# Out:
#                   EmailName  Sent  Open  Unsub  Click
# 0                Career_Ctr  2947  1404      0    257
# 1           COE_Welcome_ltr    30    17      0     10
# 2         Frost_welcome_ltr   147   126      0     23
# 3            MBS_REG_remind    64    33      0      7
# 4           MBS_Welcome_ltr   585   363      0     36
# 5     Outcomes_Values_of_UM  2974  1705      1    101
# 6           Quest_abt_Money  2953  1777      0    229
# 7           Registra_open_9    11     6      0      1
# 8          Registra_open_9b  2537  1688      0    353
# 9              Reg_reminder   527   286      0     59
# 10   Resgistration_timeline  2234  1647      0    281
# 11   SchoolofCOM_reg_remind    25     8      0      2
# 12  SchoolofCOM_Welcome_ltr   168   117      0     20
# 13           Summer_webinar  2851  1589      1    178
# 14         UGED_Welcome_ltr    11    11      0      0

# %%
# I will create a dataframe with the email header and merge it with the stats df
def subjectlineRAW(i):
    file = open(path + "/"+ i,'r')
    csvreader=csv.reader(file)
    header = next(csvreader)
    #print(header)
    line2 =next(csvreader)
    #print(line2)
    SUBJ=line2[7]
    NameofEmail = i[:-4]
    return [NameofEmail, SUBJ]

# %%
RAW_HDRS= []
for item in EM_Results:
    RAW_HDRS.append(subjectlineRAW(item))
RAW_HDRS
# Out:
# [['Career_Ctr', 'Discover and explore careers with Toppel Career Center'],
#  ['COE_Welcome_ltr', 'A message from the assistant dean'],
#  ['Frost_welcome_ltr', 'A message from the Frost School of Music'],
#  ['MBS_REG_remind', 'Registration closes July 9'],
#  ['MBS_Welcome_ltr', 'Welcome to the Miami Business School'],
#  ['Outcomes_Values_of_UM', 'Experience the value of a UM education'],
#  ['Quest_abt_Money', 'Student account resources'],
#  ['Registra_open_9', 'It?s time to register for courses!'],
#  ['Registra_open_9b', 'It?s time to register for courses!'],
#  ['Reg_reminder', 'You still need to register for classes'],
#  ['Resgistration_timeline',
#   'Learn next steps about your course registration process'],
#  ['SchoolofCOM_reg_remind', 'Registration closes July 9'],
#  ['SchoolofCOM_Welcome_ltr',
#   'A welcome from the vice dean of academic affairs'],
#  ['Summer_webinar', 'Join us for our Summer Webinar Series'],
#  ['UGED_Welcome_ltr',
#   'Welcome to the School of Education and Human Development']]

# %%
Header = pd.DataFrame(RAW_HDRS[0:],columns = ['EmailName','Header'])

# %%
Header.head(2)
# Out:
#          EmailName                                             Header
# 0       Career_Ctr  Discover and explore careers with Toppel Caree...
# 1  COE_Welcome_ltr                  A message from the assistant dean

# %%
COMBOResults = pd.merge(Header,dfESTAT, on ='EmailName', how = 'outer')

# %%
COMBOResults
# Out:
#                   EmailName  \
# 0                Career_Ctr
# 1           COE_Welcome_ltr
# 2         Frost_welcome_ltr
# 3            MBS_REG_remind
# 4           MBS_Welcome_ltr
# 5     Outcomes_Values_of_UM
# 6           Quest_abt_Money
# 7           Registra_open_9
# 8          Registra_open_9b
# 9              Reg_reminder
# 10   Resgistration_timeline
# 11   SchoolofCOM_reg_remind
# 12  SchoolofCOM_Welcome_ltr
# 13           Summer_webinar
# 14         UGED_Welcome_ltr
#
#                                                Header  Sent  Open  Unsub  \
# 0   Discover and explore careers with Toppel Caree...  2947  1404      0
# 1                   A message from the assistant dean    30    17      0
# 2            A message from the Frost School of Music   147   126      0
# 3                          Registration closes July 9    64    33      0
# 4                Welcome to the Miami Business School   585   363      0
# 5              Experience the value of a UM education  2974  1705      1
# 6                           Student account resources  2953  1777      0
# 7                  It?s time to register for courses!    11     6      0
# 8                  It?s time to register for courses!  2537  1688      0
# 9              You still need to register for classes   527   286      0
# 10  Learn next steps about your course registratio...  2234  1647      0
# 11                         Registration closes July 9    25     8      0
# 12   A welcome from the vice dean of academic affairs   168   117      0
# 13              Join us for our Summer Webinar Series  2851  1589      1
# 14  Welcome to the School of Education and Human D...    11    11      0
#
#     Click
# 0     257
# 1      10
# 2      23
# 3       7
# 4      36
# 5     101
# 6     229
# 7       1
# 8     353
# 9      59
# 10    281
# 11      2
# 12     20
# 13    178
# 14      0

# %%
#add open rate and click rate as percentages

# %%
COMBOResults['OpenRate']= pd.eval(COMBOResults.Open/COMBOResults.Sent)

# %%
COMBOResults['ClickRate']= pd.eval(COMBOResults.Click/COMBOResults.Open)

# %%
COMBOResults['Open%']= COMBOResults['OpenRate'].map(lambda n: '{:,.1%}'.format(n))

# %%
COMBOResults['Click%']= COMBOResults['ClickRate'].map(lambda n: '{:,.1%}'.format(n))

# %%
COMBOResults
# Out:
#                   EmailName  \
# 0                Career_Ctr
# 1           COE_Welcome_ltr
# 2         Frost_welcome_ltr
# 3            MBS_REG_remind
# 4           MBS_Welcome_ltr
# 5     Outcomes_Values_of_UM
# 6           Quest_abt_Money
# 7           Registra_open_9
# 8          Registra_open_9b
# 9              Reg_reminder
# 10   Resgistration_timeline
# 11   SchoolofCOM_reg_remind
# 12  SchoolofCOM_Welcome_ltr
# 13           Summer_webinar
# 14         UGED_Welcome_ltr
#
#                                                Header  Sent  Open  Unsub  \
# 0   Discover and explore careers with Toppel Caree...  2947  1404      0
# 1                   A message from the assistant dean    30    17      0
# 2            A message from the Frost School of Music   147   126      0
# 3                          Registration closes July 9    64    33      0
# 4                Welcome to the Miami Business School   585   363      0
# 5              Experience the value of a UM education  2974  1705      1
# 6                           Student account resources  2953  1777      0
# 7                  It?s time to register for courses!    11     6      0
# 8                  It?s time to register for courses!  2537  1688      0
# 9              You still need to register for classes   527   286      0
# 10  Learn next steps about your course registratio...  2234  1647      0
# 11                         Registration closes July 9    25     8      0
# 12   A welcome from the vice dean of academic affairs   168   117      0
# 13              Join us for our Summer Webinar Series  2851  1589      1
# 14  Welcome to the School of Education and Human D...    11    11      0
#
#     Click  OpenRate  ClickRate   Open% Click%
# 0     257  0.476417   0.183048   47.6%  18.3%
# 1      10  0.566667   0.588235   56.7%  58.8%
# 2      23  0.857143    0.18254   85.7%  18.3%
# 3       7  0.515625   0.212121   51.6%  21.2%
# 4      36  0.620513  0.0991736   62.1%   9.9%
# 5     101  0.573302  0.0592375   57.3%   5.9%
# 6     229  0.601761   0.128869   60.2%  12.9%
# 7       1  0.545455   0.166667   54.5%  16.7%
# 8     353  0.665353   0.209123   66.5%  20.9%
# 9      59  0.542694   0.206294   54.3%  20.6%
# 10    281  0.737243   0.170613   73.7%  17.1%
# 11      2      0.32       0.25   32.0%  25.0%
# 12     20  0.696429    0.17094   69.6%  17.1%
# 13    178  0.557348    0.11202   55.7%  11.2%
# 14      0         1          0  100.0%   0.0%

# %%
COMBOResults['OpenRate']= pd.to_numeric(COMBOResults['OpenRate'])
COMBOResults['ClickRate']= pd.to_numeric(COMBOResults['ClickRate'])
#Create columns that are plottable you have to remove the % sign you just had added
COMBOResults['Open%Plot']= COMBOResults['Open%'].str.rstrip('%').astype('float') 
COMBOResults['Click%Plot']= COMBOResults['Click%'].str.rstrip('%').astype('float')

# %%
COMBOResults.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 12 columns):
# EmailName     15 non-null object
# Header        15 non-null object
# Sent          15 non-null int64
# Open          15 non-null int64
# Unsub         15 non-null int64
# Click         15 non-null int64
# OpenRate      15 non-null float64
# ClickRate     15 non-null float64
# Open%         15 non-null object
# Click%        15 non-null object
# Open%Plot     15 non-null float64
# Click%Plot    15 non-null float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 1.5+ KB

# %%
COMBOResults
# Out:
#                   EmailName  \
# 0                Career_Ctr
# 1           COE_Welcome_ltr
# 2         Frost_welcome_ltr
# 3            MBS_REG_remind
# 4           MBS_Welcome_ltr
# 5     Outcomes_Values_of_UM
# 6           Quest_abt_Money
# 7           Registra_open_9
# 8          Registra_open_9b
# 9              Reg_reminder
# 10   Resgistration_timeline
# 11   SchoolofCOM_reg_remind
# 12  SchoolofCOM_Welcome_ltr
# 13           Summer_webinar
# 14         UGED_Welcome_ltr
#
#                                                Header  Sent  Open  Unsub  \
# 0   Discover and explore careers with Toppel Caree...  2947  1404      0
# 1                   A message from the assistant dean    30    17      0
# 2            A message from the Frost School of Music   147   126      0
# 3                          Registration closes July 9    64    33      0
# 4                Welcome to the Miami Business School   585   363      0
# 5              Experience the value of a UM education  2974  1705      1
# 6                           Student account resources  2953  1777      0
# 7                  It?s time to register for courses!    11     6      0
# 8                  It?s time to register for courses!  2537  1688      0
# 9              You still need to register for classes   527   286      0
# 10  Learn next steps about your course registratio...  2234  1647      0
# 11                         Registration closes July 9    25     8      0
# 12   A welcome from the vice dean of academic affairs   168   117      0
# 13              Join us for our Summer Webinar Series  2851  1589      1
# 14  Welcome to the School of Education and Human D...    11    11      0
#
#     Click  OpenRate  ClickRate   Open% Click%  Open%Plot  Click%Plot
# 0     257  0.476417   0.183048   47.6%  18.3%       47.6        18.3
# 1      10  0.566667   0.588235   56.7%  58.8%       56.7        58.8
# 2      23  0.857143   0.182540   85.7%  18.3%       85.7        18.3
# 3       7  0.515625   0.212121   51.6%  21.2%       51.6        21.2
# 4      36  0.620513   0.099174   62.1%   9.9%       62.1         9.9
# 5     101  0.573302   0.059238   57.3%   5.9%       57.3         5.9
# 6     229  0.601761   0.128869   60.2%  12.9%       60.2        12.9
# 7       1  0.545455   0.166667   54.5%  16.7%       54.5        16.7
# 8     353  0.665353   0.209123   66.5%  20.9%       66.5        20.9
# 9      59  0.542694   0.206294   54.3%  20.6%       54.3        20.6
# 10    281  0.737243   0.170613   73.7%  17.1%       73.7        17.1
# 11      2  0.320000   0.250000   32.0%  25.0%       32.0        25.0
# 12     20  0.696429   0.170940   69.6%  17.1%       69.6        17.1
# 13    178  0.557348   0.112020   55.7%  11.2%       55.7        11.2
# 14      0  1.000000   0.000000  100.0%   0.0%      100.0         0.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')
sns.set_context('talk')
color = sns.color_palette("Dark2",6)
fig = plt.figure()
fig.add_subplot(1,1,1)

# %%
ax = sns.barplot(y ='EmailName', x= 'Sent', data = COMBOResults)

# %%
ax2 =sns.barplot(y ='EmailName', x= 'Open', data = COMBOResults)

# %%
ax3 =sns.barplot(y ='EmailName', x= 'Open%Plot', data = COMBOResults)

# %%
ax4 =sns.barplot(y ='EmailName', x= 'Click%Plot', data = COMBOResults)

# %%
#MBS_Welcome['IntervalStartTime'] = pd.to_datetime(MBS_Welcome.IntervalStartTime)

# %%
#ax = MBS_Welcome.plot(x="IntervalStartTime", y = 'UniqueOpened')
#ax2 = MBS_Welcome.plot(x="IntervalStartTime", y = 'UniqueClicked', color ='r')
